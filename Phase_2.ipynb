# %% [markdown]
# # **Philippine Scam SMS**
# **Phase 2: Natural Language Processing**
#
# **Author/s: [Anton Reyes](https://www.github.com/AGR-yes)**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ### **Requirements and Imports**

# %% [markdown]
# #### **Imports**

# %% [markdown]
# **Basic Libraries**
#
# * `numpy` contains a large collection of mathematical functions
# * `pandas` contains functions that are designed for data manipulation and data analysis

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Visualization Libraries**
#
# * `matplotlib.pyplot` contains functions to create interactive plots
# * `seaborn` is a library based on matplotlib that allows for data visualization
# * `plotly` is an open-source graphing library for Python.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %% [markdown]
# **Natural Language Processing Libraries**
# * `re` is a module that allows the use of regular expressions
# * `spaCy` is an NLP library for "understand" lrge volumes of text
# * `WordCloud` is a tool to show the most frequently used word in the dataset
# * `NLTK` is an open-source library for NLP and linguistics
# * `scikit-learn` is a library for machine learning models and statistical modeling

# %%
import re
import spacy
from wordcloud import WordCloud, STOPWORDS

import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import text
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### **Datasets and Files**

# %% [markdown]
# The following files were used for this project:
#
# - `proof.csv` contains features `proof` and `name` only after Phase 1. This does not contain the type of spam and lacks classification.
# - `genediazjr-tagalog.txt` used to add _Tagalog_ Stopwords for NLP

# %% [markdown]
# ## **Data Collection**

# %% [markdown]
# Importing the dataset using pandas.

# %%
dataset = "Processed Datasets\proof.csv"

proof = pd.read_csv(dataset)
proof.tail()
# Out:
#                                                   proof   name type
# 5037  Araw-araw na suweld0 5000, kai1angan lang ng 1...  False  NaN
# 5038  Goodnews! VIP perks at SUGARPLAY Sign up & Cla...  False  NaN
# 5039   Start referring & earning at SUGARPLAY Earn e...   True  NaN
# 5040  , Experience the thrill at JackpotCity! Enjoy ...   True  NaN
# 5041  , Get 5% Deposit bonus using PAYMAYA at UNIBET...   True  NaN

# %% [markdown]
# ## **Description of the Dataset**

# %% [markdown]
# Here, we find the shape of the dataset.

# %%
proof.shape
# Out:
# (5042, 3)

# %% [markdown]
# By looking at the `info` of the dataframe, we can see that there are `non-null` values.

# %%
proof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5042 entries, 0 to 5041
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   proof   1414 non-null   object
#  1   name    5042 non-null   bool
#  2   type    4679 non-null   object
# dtypes: bool(1), object(2)
# memory usage: 83.8+ KB

# %% [markdown]
# ## **Exploratory Data Analysis (Raw Text)**

# %% [markdown]
# ### **Wordcloud**

# %%
#get non-null values
proof_filtered = proof[proof['proof'].notnull()].reset_index(drop=True)
proof_filtered
# Out:
#                                                   proof   name       type
# 0                                                  POEA  False     others
# 1                                                  POEA  False     others
# 2                                     Federal Partylist  False  political
# 3                                    Build Build Build   False  political
# 4                                   luckyphil.com/login  False      lotto
# ...                                                 ...    ...        ...
# 1409  Araw-araw na suweld0 5000, kai1angan lang ng 1...  False        NaN
# 1410  Goodnews! VIP perks at SUGARPLAY Sign up & Cla...  False        NaN
# 1411   Start referring & earning at SUGARPLAY Earn e...   True        NaN
# 1412  , Experience the thrill at JackpotCity! Enjoy ...   True        NaN
# 1413  , Get 5% Deposit bonus using PAYMAYA at UNIBET...   True        NaN
#
# [1414 rows x 3 columns]

# %%
proof_filtered['proof'] = [str(value) for value in proof_filtered['proof']]

# %%
proof_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   proof   1414 non-null   object
#  1   name    1414 non-null   bool
#  2   type    1228 non-null   object
# dtypes: bool(1), object(2)
# memory usage: 23.6+ KB

# %%
text = " ".join(i for i in proof_filtered.proof)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# %%
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### **Top Words**

# %%
#get top 25 words with count into a dataframe
raw_top25 = pd.DataFrame(FreqDist(text.split()).most_common(25), columns=['word','count'])

raw_top25
# Out:
#        word  count
# 0        ng    336
# 1        to    323
# 2        at    314
# 3       and    262
# 4        sa    242
# 5        na    229
# 6       ang    173
# 7        up    155
# 8       for    148
# 9       you    136
# 10      the    136
# 11     your    135
# 12        !    115
# 13      now    114
# 14     para    104
# 15      get     92
# 16        a     84
# 17    bonus     83
# 18        ,     78
# 19       ka     73
# 20       in     70
# 21  message     68
# 22   LIGHTS     67
# 23       of     67
# 24        &     64

# %% [markdown]
# We can see that a lot of the punctuation were considered as a word and that there is a mix of stopwords in both the English and Tagalog language.

# %% [markdown]
# ## **Natural Language Processing**

# %% [markdown]
# ### **Text Cleaning**

# %% [markdown]
# #### **Stopwords Preparation**

# %%
#list of stopwords
en_stopwords = set(STOPWORDS)
en_stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
#import txt as list
with open('Supplemental Datasets\genediazjr-tagalog.txt', 'r') as f:
    tl_stopwords = f.read().splitlines()

tl_stopwords
# Out:
# ['ako',
#  'sa',
#  'akin',
#  'ko',
#  'aking',
#  'sarili',
#  'kami',
#  'atin',
#  'ang',
#  'aming',
#  'amin',
#  'ating',
#  'ka',
#  'iyong',
#  'iyo',
#  'inyong',
#  'siya',
#  'kanya',
#  'mismo',
#  'ito',
#  'nito',
#  'kanyang',
#  'sila',
#  'nila',
#  'kanila',
#  'kanilang',
#  'kung',
#  'ano',
#  'alin',
#  'sino',
#  'kanino',
#  'na',
#  'mga',
#  'iyon',
#  'am',
#  'ay',
#  'maging',
#  'naging',
#  'mayroon',
#  'may',
#  'nagkaroon',
#  'pagkakaroon',
#  'gumawa',
#  'ginagawa',
#  'ginawa',
#  'paggawa',
#  'ibig',
#  'dapat',
#  'maaari',
#  'marapat',
#  'kong',
#  'ikaw',
#  'tayo',
#  'hindi',
#  'namin',
#  'gusto',
#  'nais',
#  'niyang',
#  'nilang',
#  'niya',
#  'huwag',
#  'ginawang',
#  'gagawin',
#  'maaaring',
#  'sabihin',
#  'narito',
#  'kapag',
#  'ni',
#  'nasaan',
#  'bakit',
#  'paano',
#  'kailangan',
#  'walang',
#  'katiyakan',
#  'isang',
#  'at',
#  'pero',
#  'o',
#  'dahil',
#  'bilang',
#  'hanggang',
#  'habang',
#  'ng',
#  'pamamagitan',
#  'para',
#  'tungkol',
#  'laban',
#  'pagitan',
#  'panahon',
#  'bago',
#  'pagkatapos',
#  'itaas',
#  'ibaba',
#  'mula',
#  'pataas',
#  'pababa',
#  'palabas',
#  'ibabaw',
#  'ilalim',
#  'muli',
#  'pa',
#  'minsan',
#  'dito',
#  'doon',
#  'saan',
#  'lahat',
#  'anumang',
#  'kapwa',
#  'bawat',
#  'ilan',
#  'karamihan',
#  'iba',
#  'tulad',
#  'lamang',
#  'pareho',
#  'kaya',
#  'kaysa',
#  'masyado',
#  'napaka',
#  'isa',
#  'bababa',
#  'kulang',
#  'marami',
#  'ngayon',
#  'kailanman',
#  'sabi',
#  'nabanggit',
#  'din',
#  'kumuha',
#  'pumunta',
#  'pumupunta',
#  'ilagay',
#  'makita',
#  'nakita',
#  'katulad',
#  'mahusay',
#  'likod',
#  'kahit',
#  'paraan',
#  'noon',
#  'gayunman',
#  'dalawa',
#  'tatlo',
#  'apat',
#  'lima',
#  'una',
#  'pangalawa']

# %%
#add 'mo' and 'lang' to tl_stopwords
tl_stopwords.extend(['mo', 'lang'])

# %%
#merging en_stopwords and tl_stopwords
stopwords = en_stopwords.union(tl_stopwords)
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'akin',
#  'aking',
#  'ako',
#  'alin',
#  'all',
#  'also',
#  'am',
#  'amin',
#  'aming',
#  'an',
#  'and',
#  'ang',
#  'ano',
#  'anumang',
#  'any',
#  'apat',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'atin',
#  'ating',
#  'ay',
#  'bababa',
#  'bago',
#  'bakit',
#  'bawat',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'bilang',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'dahil',
#  'dalawa',
#  'dapat',
#  'did',
#  "didn't",
#  'din',
#  'dito',
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'doon',
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'gagawin',
#  'gayunman',
#  'get',
#  'ginagawa',
#  'ginawa',
#  'ginawang',
#  'gumawa',
#  'gusto',
#  'habang',
#  'had',
#  "hadn't",
#  'hanggang',
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'hindi',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'huwag',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'iba',
#  'ibaba',
#  'ibabaw',
#  'ibig',
#  'if',
#  'ikaw',
#  'ilagay',
#  'ilalim',
#  'ilan',
#  'in',
#  'into',
#  'inyong',
#  'is',
#  'isa',
#  'isang',
#  "isn't",
#  'it',
#  "it's",
#  'itaas',
#  'ito',
#  'its',
#  'itself',
#  'iyo',
#  'iyon',
#  'iyong',
#  'just',
#  'k',
#  'ka',
#  'kahit',
#  'kailangan',
#  'kailanman',
#  'kami',
#  'kanila',
#  'kanilang',
#  'kanino',
#  'kanya',
#  'kanyang',
#  'kapag',
#  'kapwa',
#  'karamihan',
#  'katiyakan',
#  'katulad',
#  'kaya',
#  'kaysa',
#  'ko',
#  'kong',
#  'kulang',
#  'kumuha',
#  'kung',
#  'laban',
#  'lahat',
#  'lamang',
#  'lang',
#  "let's",
#  'like',
#  'likod',
#  'lima',
#  'maaari',
#  'maaaring',
#  'maging',
#  'mahusay',
#  'makita',
#  'marami',
#  'marapat',
#  'masyado',
#  'may',
#  'mayroon',
#  'me',
#  'mga',
#  'minsan',
#  'mismo',
#  'mo',
#  'more',
#  'most',
#  'mula',
#  'muli',
#  "mustn't",
#  'my',
#  'myself',
#  'na',
#  'nabanggit',
#  'naging',
#  'nagkaroon',
#  'nais',
#  'nakita',
#  'namin',
#  'napaka',
#  'narito',
#  'nasaan',
#  'ng',
#  'ngayon',
#  'ni',
#  'nila',
#  'nilang',
#  'nito',
#  'niya',
#  'niyang',
#  'no',
#  'noon',
#  'nor',
#  'not',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'pa',
#  'paano',
#  'pababa',
#  'paggawa',
#  'pagitan',
#  'pagkakaroon',
#  'pagkatapos',
#  'palabas',
#  'pamamagitan',
#  'panahon',
#  'pangalawa',
#  'para',
#  'paraan',
#  'pareho',
#  'pataas',
#  'pero',
#  'pumunta',
#  'pumupunta',
#  'r',
#  'sa',
#  'saan',
#  'sabi',
#  'sabihin',
#  'same',
#  'sarili',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'sila',
#  'since',
#  'sino',
#  'siya',
#  'so',
#  'some',
#  'such',
#  'tatlo',
#  'tayo',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'tulad',
#  'tungkol',
#  'una',
#  'under',
#  'until',
#  'up',
#  'very',
#  'walang',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %% [markdown]
# #### **Removing Stopwords**

# %%
#remove stopwords from dataset
text_only = proof_filtered.copy()

text_only['proof'] = text_only['proof'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

text_only.head()
# Out:
#                  proof   name       type
# 0                 POEA  False     others
# 1                 POEA  False     others
# 2    Federal Partylist  False  political
# 3    Build Build Build  False  political
# 4  luckyphil.com/login  False      lotto

# %%
#remove STOPWORDS from dataframe
text_only = text_only[text_only['proof'].notnull()].reset_index(drop=True)
text_only
# Out:
#                                                   proof   name       type
# 0                                                  POEA  False     others
# 1                                                  POEA  False     others
# 2                                     Federal Partylist  False  political
# 3                                     Build Build Build  False  political
# 4                                   luckyphil.com/login  False      lotto
# ...                                                 ...    ...        ...
# 1409  Araw-araw suweld0 5000, kai1angan 1-2 oras is@...  False        NaN
# 1410  Goodnews! VIP perks SUGARPLAY Sign & Claim PHP...  False        NaN
# 1411  Start referring & earning SUGARPLAY Earn everd...   True        NaN
# 1412  , Experience thrill JackpotCity! Enjoy 5% USDT...   True        NaN
# 1413  , Get 5% Deposit bonus using PAYMAYA UNIBET! I...   True        NaN
#
# [1414 rows x 3 columns]

# %% [markdown]
# #### **Removing Punctuation and Other Strings**

# %%
#remove punctuations from dataframe
text_only['proof'] = text_only['proof'].str.replace('[^\w\s]','')
text_only
# Out:
# C:\Users\Mos\AppData\Local\Temp\ipykernel_9020\2214577564.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_only['proof'] = text_only['proof'].str.replace('[^\w\s]','')
#                                                   proof   name       type
# 0                                                  POEA  False     others
# 1                                                  POEA  False     others
# 2                                     Federal Partylist  False  political
# 3                                     Build Build Build  False  political
# 4                                     luckyphilcomlogin  False      lotto
# ...                                                 ...    ...        ...
# 1409  Arawaraw suweld0 5000 kai1angan 12 oras isng a...  False        NaN
# 1410  Goodnews VIP perks SUGARPLAY Sign  Claim PHP14...  False        NaN
# 1411  Start referring  earning SUGARPLAY Earn everda...   True        NaN
# 1412   Experience thrill JackpotCity Enjoy 5 USDT De...   True        NaN
# 1413   Get 5 Deposit bonus using PAYMAYA UNIBET Invi...   True        NaN
#
# [1414 rows x 3 columns]

# %%
remove = ['httpstlystsH','https://t.ly/stsH','https','&', 'amp', 'amp;', 'tly', 't', 'ly', 'co', 'com', 'www', 'http']

#removing words from dataframe with `remove`
text_only['proof'] = text_only['proof'].apply(lambda x: ' '.join([word for word in x.split() if word not in (remove)]))

#removing single letters with regex
text_only['proof'] = text_only['proof'].str.replace(r'\b[a-zA-Z]\b', '')
# Out:
# C:\Users\Mos\AppData\Local\Temp\ipykernel_9020\2517495946.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   text_only['proof'] = text_only['proof'].str.replace(r'\b[a-zA-Z]\b', '')

# %% [markdown]
# ### **Classification**
#
# In the `spam.csv` dataset, the needed features such as the `proof` and the `name` are present. However, to add more to the analysis, we can do classification through machine learning with Natural Language Processing techniques.

# %% [markdown]
# ### **Preparation**

# %%
text_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   proof   1414 non-null   object
#  1   name    1414 non-null   bool
#  2   type    1228 non-null   object
# dtypes: bool(1), object(2)
# memory usage: 23.6+ KB

# %%
text_only.isnull().sum()
# Out:
# proof      0
# name       0
# type     186
# dtype: int64

# %%
#tokenize words in labelled dataset
text_only['token'] = text_only['proof'].apply(lambda x: word_tokenize(x))

text_only.head()
# Out:
#                proof   name       type                  token
# 0               POEA  False     others                 [POEA]
# 1               POEA  False     others                 [POEA]
# 2  Federal Partylist  False  political   [Federal, Partylist]
# 3  Build Build Build  False  political  [Build, Build, Build]
# 4  luckyphilcomlogin  False      lotto    [luckyphilcomlogin]

# %%
text_only['proof'] = text_only['proof'].astype(str).str.lower()

# %% [markdown]
# #### **Separation of Dataset**

# %%
#separating the dataset into labelled and unlabelled
no_label = text_only[text_only['type'].isnull()].reset_index(drop=True)

labelled = text_only[text_only['type'].notnull()].reset_index(drop=True)

# %% [markdown]
# #### **Class Merging**
#
# From the `phase 1` notebook, the labels in the select dataset were originally unclean. But after cleaning, the labels (or classes) were organized. However, to have a better accuracy score, we would need to filter the labels one more time.

# %%
labelled['type'].value_counts()
# Out:
# others             241
# casino/gambling    181
# money               98
# not specified       89
# online games        82
# loan/bank           70
# raffle/play         58
# products            56
# work                55
# claiming            46
# email               44
# platform            42
# online shopping     31
# job offer           30
# free                27
# rewards             13
# deposit scam        12
# raffle              12
# netflix             10
# passive income       7
# lotto                7
# political            6
# gcash                6
# unclaimed bonus      4
# fake news            1
# Name: type, dtype: int64

# %%
#changing the text in type column to another stringwith dictionary
labelled['type'] = labelled['type'].replace(['money', 'gcash', 'loan/bank', 'deposit scam'], "bank/money")
labelled['type'] = labelled['type'].replace(['raffle/play', 'lotto', 'raffle', 'claiming'], "casino/gambling")
labelled['type'] = labelled['type'].replace(['job offer','passive income'], "work")
labelled['type'] = labelled['type'].replace(['online shopping', 'email', 'netflix', 'online games','platform'], "online activity")
labelled['type'] = labelled['type'].replace(['products', 'free', 'rewards'], "free")
labelled['type'] = labelled['type'].replace(['not specified', 'unclaimed bonus','fake news', 'political'], "others")

labelled['type'].value_counts()
# Out:
# others             341
# casino/gambling    304
# online activity    209
# bank/money         186
# free                96
# work                92
# Name: type, dtype: int64

# %% [markdown]
# ### **Feature Extraction**

# %%
#Splitting the dataset into train and test

X = labelled['token']
y = labelled['type']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, 
                                                    stratify=None, 
                                                    random_state=42)

# %% [markdown]
# **Vectorizing**

# %%
X_train = [' '.join(tokens) for tokens in X_train]
X_test = [' '.join(tokens) for tokens in X_test]

# Creating the vectorizer
vectorizer = TfidfVectorizer(stop_words=stopwords)

# Fitting the vectorizer on the training data
X_train_tfidf = vectorizer.fit_transform(X_train)

# Transforming the testing data using the fitted vectorizer
X_test_tfidf = vectorizer.transform(X_test)
# Out:
# c:\Users\Mos\anaconda3\envs\Dash\lib\site-packages\sklearn\feature_extraction\text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'didn', 'doesn', 'don', 'hadn', 'hasn', 'haven', 'isn', 'let', 'll', 'mustn', 're', 'shan', 'shouldn', 've', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
#   warnings.warn(

# %% [markdown]
# **Label Encoding**

# %%
label_encoder = LabelEncoder()

# Fit the encoder on the target variable
label_encoder.fit(y_train)

# Transform the target variable into numerical labels
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %% [markdown]
# **Classifier**
#
# Here, we check for the accuracy score for the labelled dataset with the different possible models

# %%
#initializing the classifiers
classifiers = [
    MultinomialNB(),
    SVC(),
    RandomForestClassifier(),
    LogisticRegression()
]

#training and evaluate each classifier
for classifier in classifiers:
    #training the classifier on the vectorized training data
    classifier.fit(X_train_tfidf, y_train_encoded)
    
    #predicting the labels for the testing data
    y_pred = classifier.predict(X_test_tfidf)
    
    #computing the accuracy
    accuracy = accuracy_score(y_test_encoded, y_pred)
    print(classifier.__class__.__name__, "Accuracy:", round(accuracy*100, 2), "%")
# Out:
# MultinomialNB Accuracy: 47.15 %
# SVC Accuracy: 47.56 %
# RandomForestClassifier Accuracy: 50.41 %
# LogisticRegression Accuracy: 48.37 %

# %% [markdown]
# Since all the accuracy scores are quite low, I'll be using the model with the highest score: `RandomForestClassifier()`. Though typically we would go for higher scores, resources for a project with a topic like this, is quite limited - especially in the Philippines.

# %% [markdown]
# ### **Prediction**

# %%
no_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   proof   186 non-null    object
#  1   name    186 non-null    bool
#  2   type    0 non-null      object
#  3   token   186 non-null    object
# dtypes: bool(1), object(3)
# memory usage: 4.7+ KB

# %%
model = RandomForestClassifier()

model.fit(X_train_tfidf, y_train_encoded)
# Out:
# RandomForestClassifier()

# %%
#filling any missing values with an empty string
no_label['proof'] = no_label['proof'].fillna('')


#extracting the features from the new DataFrame
X_new = no_label['proof'].astype(str)  # Replace "feature_column" with the appropriate column name


#vectorizing the new data using the same vectorizer from training
X_new_tfidf = vectorizer.transform(X_new)

#making predictions using the loaded model
predictions = model.predict(X_new_tfidf)

#mapping numeric labels back to original class labels
predicted_classes = [label_encoder.inverse_transform([label])[0] for label in predictions]

#adding the predicted classes to the new DataFrame
no_label['predicted_class'] = predicted_classes

print(no_label['predicted_class'])
# Out:
# 0      casino/gambling
# 1      casino/gambling
# 2               others
# 3      casino/gambling
# 4               others
#             ...
# 181    casino/gambling
# 182    casino/gambling
# 183    casino/gambling
# 184    online activity
# 185             others
# Name: predicted_class, Length: 186, dtype: object

# %%
print(new_data['predicted_class'].value_counts())

print('Accuracy: ',round(accuracy_score(y_test_encoded, y_pred)*100,  2), "%")
# Out:
# casino/gambling    94
# others             65
# online activity    19
# bank/money          8
# Name: predicted_class, dtype: int64
# Accuracy:  48.37 %

# %% [markdown]
# ### **Merging the Datasets**

# %%
#merging the unlabelled and labelled datasets
merged = pd.concat([labelled, no_label], ignore_index=True)

merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   proof            1414 non-null   object
#  1   name             1414 non-null   bool
#  2   type             1228 non-null   object
#  3   token            1414 non-null   object
#  4   predicted_class  186 non-null    object
# dtypes: bool(1), object(4)
# memory usage: 45.7+ KB

# %%
#inserting the non-null values from the predicted_class column into the Nan values in the type column
merged['type'] = merged['type'].fillna(merged['predicted_class'])

merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   proof            1414 non-null   object
#  1   name             1414 non-null   bool
#  2   type             1414 non-null   object
#  3   token            1414 non-null   object
#  4   predicted_class  186 non-null    object
# dtypes: bool(1), object(4)
# memory usage: 45.7+ KB

# %% [markdown]
# ## **Exploratory Data Analysis (Cleaned Text)**

# %% [markdown]
# **WordCloud**

# %%
#wordcloud
text = " ".join(i for i in merged.proof)
wordcloud = WordCloud(stopwords=stopwords, background_color="black", colormap = "Greens").generate(text)

plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# **Top Words**

# %%
#top 100 words with count from dataframe
top = pd.DataFrame(FreqDist(merged['proof'].str.cat(sep=' ').split()).most_common(100), columns=['word','count'])
top
# Out:
#           word  count
# 0        bonus    211
# 1          now    206
# 2         cash    126
# 3         free    113
# 4         name    107
# ..         ...    ...
# 95  interested     26
# 96         vip     25
# 97   immediate     25
# 98        text     24
# 99      piraso     24
#
# [100 rows x 2 columns]

# %% [markdown]
# # **Saving**

# %%
#top.to_csv('Processed Datasets/top100_words.csv', index=False)
#text_only.to_csv('Processed Datasets/proof_cleaned.csv', index=False)

#saving wordcloud as png
#wordcloud.to_file('wordcloud.png')
